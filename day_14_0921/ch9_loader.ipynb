# %% [markdown]
# ### 문서 Loader

# %%
# !pip --version
# Out:
# pip 25.0.1 from C:\pkh20260902\ex0921\.venv\Lib\site-packages\pip (python 3.12)

# %%
# !pip install -U langchain_community

# %%
from langchain_core.documents import Document

document = Document(page_content="Hello, this is a langchain document.")

# %%
document.__dict__
# Out:
# {'id': None,
#  'metadata': {},
#  'page_content': 'Hello, this is a langchain document.',
#  'type': 'Document'}

# %%
document.metadata["source"] = "TeddyNote"
document.metadata["page"] = 1
document.metadata["author"] = "Teddy"

document.metadata
# Out:
# {'source': 'TeddyNote', 'page': 1, 'author': 'Teddy'}

# %%
FILE_PATH = r"langchain-kr\06-DocumentLoader\SPRI_AI_Brief_2023년12월호_F.pdf"

# %%
from langchain_community.document_loaders import PyPDFLoader

loader = PyPDFLoader(FILE_PATH)

# %%
# !pip install pypdf

# %%
docs = loader.load()

len(docs)
# Out:
# 23

# %%
docs[1]
# Out:
# Document(metadata={'producer': 'Hancom PDF 1.3.0.542', 'creator': 'Hwp 2018 10.0.0.13462', 'creationdate': '2023-12-08T13:28:38+09:00', 'author': 'dj', 'moddate': '2023-12-08T13:28:38+09:00', 'pdfversion': '1.4', 'source': 'langchain-kr\\06-DocumentLoader\\SPRI_AI_Brief_2023년12월호_F.pdf', 'total_pages': 23, 'page': 1, 'page_label': '2'}, page_content='2023년 12월호\nⅠ. 인공지능 산업 동향 브리프\n 1. 정책/법제 \n   ▹ 미국, 안전하고 신뢰할 수 있는 AI 개발과 사용에 관한 행정명령 발표  ·························1\n   ▹ G7, 히로시마 AI 프로세스를 통해 AI 기업 대상 국제 행동강령에 합의 ···························2\n   ▹ 영국 AI 안전성 정상회의에 참가한 28개국, AI 위험에 공동 대응 선언 ···························3\n   ▹ 미국 법원, 예술가들이 생성 AI 기업에 제기한 저작권 소송 기각 ·····································4\n   ▹ 미국 연방거래위원회, 저작권청에 소비자 보호와 경쟁 측면의 AI 의견서 제출 ·················5\n   ▹ EU AI 법 3자 협상, 기반모델 규제 관련 견해차로 난항 ···················································6\n \n 2. 기업/산업 \n   ▹ 미국 프런티어 모델 포럼, 1,000만 달러 규모의 AI 안전 기금 조성 ································7\n   ▹ 코히어, 데이터 투명성 확보를 위한 데이터 출처 탐색기
# ...

# %%
from langchain_text_splitters import RecursiveCharacterTextSplitter

text_splitter = RecursiveCharacterTextSplitter(chunk_size=200, chunk_overlap=0)

FILE_PATH = r"langchain-kr\06-DocumentLoader\SPRI_AI_Brief_2023년12월호_F.pdf"

loader = PyPDFLoader(FILE_PATH)

split_docs = loader.load_and_split(text_splitter=text_splitter)

# %%
print(f"문서의 길이: {len(split_docs)}")

split_docs[10]
# Out:
# 문서의 길이: 173
# Document(metadata={'producer': 'Hancom PDF 1.3.0.542', 'creator': 'Hwp 2018 10.0.0.13462', 'creationdate': '2023-12-08T13:28:38+09:00', 'author': 'dj', 'moddate': '2023-12-08T13:28:38+09:00', 'pdfversion': '1.4', 'source': 'langchain-kr\\06-DocumentLoader\\SPRI_AI_Brief_2023년12월호_F.pdf', 'total_pages': 23, 'page': 1, 'page_label': '2'}, page_content='Ⅱ. 주요 행사\n   ▹CES 2024 ·····························································································································19')

# %%
loader.lazy_load()

for doc in loader.lazy_load():
    print(doc.metadata)
# Out:
# {'producer': 'Hancom PDF 1.3.0.542', 'creator': 'Hwp 2018 10.0.0.13462', 'creationdate': '2023-12-08T13:28:38+09:00', 'author': 'dj', 'moddate': '2023-12-08T13:28:38+09:00', 'pdfversion': '1.4', 'source': 'langchain-kr\\06-DocumentLoader\\SPRI_AI_Brief_2023년12월호_F.pdf', 'total_pages': 23, 'page': 0, 'page_label': '1'}
# {'producer': 'Hancom PDF 1.3.0.542', 'creator': 'Hwp 2018 10.0.0.13462', 'creationdate': '2023-12-08T13:28:38+09:00', 'author': 'dj', 'moddate': '2023-12-08T13:28:38+09:00', 'pdfversion': '1.4', 'source': 'langchain-kr\\06-DocumentLoader\\SPRI_AI_Brief_2023년12월호_F.pdf', 'total_pages': 23, 'page': 1, 'page_label': '2'}
# {'producer': 'Hancom PDF 1.3.0.542', 'creator': 'Hwp 2018 10.0.0.13462', 'creationdate': '2023-12-08T13:28:38+09:00', 'author': 'dj', 'moddate': '2023-12-08T13:28:38+09:00', 'pdfversion': '1.4', 'source': 'langchain-kr\\06-DocumentLoader\\SPRI_AI_Brief_2023년12월호_F.pdf', 'total_pages': 23, 'page': 2, 'page_label': '3'}
# ...

# %%
adocs = loader.aload()

# %%
await adocs
# Out:
# [Document(metadata={'producer': 'Hancom PDF 1.3.0.542', 'creator': 'Hwp 2018 10.0.0.13462', 'creationdate': '2023-12-08T13:28:38+09:00', 'author': 'dj', 'moddate': '2023-12-08T13:28:38+09:00', 'pdfversion': '1.4', 'source': 'langchain-kr\\06-DocumentLoader\\SPRI_AI_Brief_2023년12월호_F.pdf', 'total_pages': 23, 'page': 0, 'page_label': '1'}, page_content='2023년 12월호'),
# ...

# %% [markdown]
# ### PDF Loader

# %%
from dotenv import load_dotenv

load_dotenv()

FILE_PATH = r"langchain-kr\06-DocumentLoader\SPRI_AI_Brief_2023년12월호_F.pdf"

# %%
# !pip install -qU pypdf

# %%
from langchain_community.document_loaders import PyPDFLoader

loader = PyPDFLoader(FILE_PATH)

docs = loader.load()

print(docs[10].page_content[:300])
# Out:
# SPRi AI Brief |
# 2023-12월호
# 8
# 코히어, 데이터 투명성 확보를 위한 데이터 출처 탐색기 공개
# n 코히어와 12개 기관이  광범위한 데이터셋에 대한 감사를 통해 원본 데이터 출처, 재라이선스 상태,
# 작성자 등 다양한 정보를 제공하는 ‘데이터 출처 탐색기’ 플랫폼을 출시
# n 대화형 플랫폼을 통해 개발자는 데이터셋의 라이선스 상태를 쉽게 파악할 수 있으며 데이터셋의
# 구성과 계보도 추적 가능
# KEY Contents
# £ 데이터 출처 탐색기, 광범위한 데이터셋 정보 제공을 통해 데이터 투명성 향상
# n AI 기업 코히어

# %%
# !pip install langchain_teddynote

# %% [markdown]
# ### CSV Loader & DataFrame Loader

# %%
from langchain_community.document_loaders.csv_loader import CSVLoader

loader = CSVLoader(file_path=r"langchain-kr\06-DocumentLoader\data\titanic.csv")

docs = loader.load()

print(len(docs))
print(docs[0].metadata)
# Out:
# 891
# {'source': 'langchain-kr\\06-DocumentLoader\\data\\titanic.csv', 'row': 0}

# %%
print(docs[1].page_content)
# Out:
# PassengerId: 2
# Survived: 1
# Pclass: 1
# Name: Cumings, Mrs. John Bradley (Florence Briggs Thayer)
# Sex: female
# Age: 38
# SibSp: 1
# Parch: 0
# Ticket: PC 17599
# Fare: 71.2833
# Cabin: C85
# Embarked: C

# %%
loader = CSVLoader(
    file_path=r"langchain-kr\06-DocumentLoader\data\titanic.csv",
    csv_args={
        "delimiter": ",",
        "quotechar": '"',
        "fieldnames": [
            "Passenger ID",
            "Survival (1: Survived, 0: Died)",
            "Passenger Class",
            "Name",
            "Sex",
            "Age",
            "Number of Siblings/Spouses Aboard",
            "Number of Parents/Children Aboard",
            "Ticket Number",
            "Fare",
            "Cabin",
            "Port of Embarkation",
        ],
    },
)

docs = loader.load()

print(docs[1].page_content)
# Out:
# Passenger ID: 1
# Survival (1: Survived, 0: Died): 0
# Passenger Class: 3
# Name: Braund, Mr. Owen Harris
# Sex: male
# Age: 22
# Number of Siblings/Spouses Aboard: 1
# Number of Parents/Children Aboard: 0
# Ticket Number: A/5 21171
# Fare: 7.25
# Cabin:
# Port of Embarkation: S

# %%
row = docs[1].page_content.split("\n")
row_str = "<row>"
for element in row:
    splitted_element = element.split(":")
    value = splitted_element[-1]
    col = ":".join(splitted_element[:-1])
    row_str += f"<{col}>{value.strip()}</{col}>"
row_str += "</row>"
print(row_str)
# Out:
# <row><Passenger ID>1</Passenger ID><Survival (1: Survived, 0: Died)>0</Survival (1: Survived, 0: Died)><Passenger Class>3</Passenger Class><Name>Braund, Mr. Owen Harris</Name><Sex>male</Sex><Age>22</Age><Number of Siblings/Spouses Aboard>1</Number of Siblings/Spouses Aboard><Number of Parents/Children Aboard>0</Number of Parents/Children Aboard><Ticket Number>A/5 21171</Ticket Number><Fare>7.25</Fare><Cabin></Cabin><Port of Embarkation>S</Port of Embarkation></row>

# %%
for doc in docs:
    row = doc.page_content.split("\n")
    row_str = "<row>"
    for element in row:
        splitted_element = element.split(":")
        value = splitted_element[-1]
        col = ":".join(splitted_element[:-1])
        row_str += f"<{col}>{value.strip()}</{col}>"
    row_str += "</row>"
    print(row_str)
# Out:
# <row><Passenger ID>PassengerId</Passenger ID><Survival (1: Survived, 0: Died)>Survived</Survival (1: Survived, 0: Died)><Passenger Class>Pclass</Passenger Class><Name>Name</Name><Sex>Sex</Sex><Age>Age</Age><Number of Siblings/Spouses Aboard>SibSp</Number of Siblings/Spouses Aboard><Number of Parents/Children Aboard>Parch</Number of Parents/Children Aboard><Ticket Number>Ticket</Ticket Number><Fare>Fare</Fare><Cabin>Cabin</Cabin><Port of Embarkation>Embarked</Port of Embarkation></row>
# <row><Passenger ID>1</Passenger ID><Survival (1: Survived, 0: Died)>0</Survival (1: Survived, 0: Died)><Passenger Class>3</Passenger Class><Name>Braund, Mr. Owen Harris</Name><Sex>male</Sex><Age>22</Age><Number of Siblings/Spouses Aboard>1</Number of Siblings/Spouses Aboard><Number of Parents/Children Aboard>0</Number of Parents/Children Aboard><Ticket Number>A/5 21171</Ticket Number><Fare>7.25</Fare><Cabin></Cabin><Port of Embarkation>S</Port of Embarkation></row>
# ...

# %%
loader = CSVLoader(
    file_path=r"langchain-kr\06-DocumentLoader\data\titanic.csv", source_column="PassengerId"
)

docs = loader.load()

print(docs[1])
# Out:
# page_content='PassengerId: 2
# Survived: 1
# Pclass: 1
# Name: Cumings, Mrs. John Bradley (Florence Briggs Thayer)
# Sex: female
# Age: 38
# SibSp: 1
# Parch: 0
# Ticket: PC 17599
# Fare: 71.2833
# Cabin: C85
# Embarked: C' metadata={'source': '2', 'row': 1}

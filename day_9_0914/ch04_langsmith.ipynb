# %% [markdown]
# ### LangSmith

# %%
# !pip --version
# Out:
# pip 26.2.1 from C:\pkh20260902\ex0914\.venv\Lib\site-packages\pip (python 3.12)

# %%
from dotenv import load_dotenv

load_dotenv()
# Out:
# True

# %%
# !pip install -U langchain langchain-openai

# %%
from dotenv import load_dotenv
import os

# .env 파일 로드 (override=False가 기본값이므로 시스템 환경변수가 우선순위를 가집니다)
load_dotenv()

# 정상 로드 확인 테스트
print("OpenAI 키:", os.getenv("OPENAI_API_KEY")[:8] + "...")
print("LANGSMITH 키:", os.getenv("LANGSMITH_API_KEY")[:8] + "...")
print("LangSmith 프로젝트:", os.getenv("LANGSMITH_PROJECT"))
# Out:
# OpenAI 키: sk-proj-...
# LANGSMITH 키: lsv2_pt_...
# LangSmith 프로젝트: test0914

# %%
from langchain_openai import ChatOpenAI

llm = ChatOpenAI(model="gpt-4o-mini")
question = "What is the population of Tokyo?"
response = llm.invoke(question)

# %%
print(response.content)
# Out:
# As of my last update in October 2023, the population of Tokyo is estimated to be around 14 million people in the central 23 wards. However, if you consider the Greater Tokyo Area, which includes the surrounding prefectures, the population is approximately 37 million, making it one of the most populous metropolitan areas in the world. For the most current figures, I recommend checking the latest statistics from a reliable source, such as government publications or demographic studies.

# %%
from langchain_openai import ChatOpenAI
from langchain_core.tools import tool
from langchain.agents import create_agent

# 1. Tool 정의
@tool
def get_weather(city: str) -> str:
    """Get weather for a given city."""
    return f"It's always sunny in {city}!"

# 2. 모델 및 에이전트 연결
llm = ChatOpenAI(model="gpt-4o-mini", temperature=0)
agent = create_agent(model=llm, tools=[get_weather])

# 3. 실행
result = agent.invoke({"messages": [("user", "San Francisco 날씨 어때?")]})
print(result["messages"][-1].content)

# LangSmith Tracing에서 확인하기
# Out:
# 샌프란시스코의 날씨는 항상 맑습니다!

# %%
# !pip install langchain_teddynote

# %%
from langchain_teddynote import logging

# %%
# LangSmith 추적하기
logging.langsmith("test0914", set_enable=True)
# Out:
# LangSmith 추적을 시작합니다.
# [프로젝트명]
# test0914

# %%
# LangSmith 추적하지 않기
logging.langsmith("test0914", set_enable=False)
# Out:
# LangSmith 추적을 하지 않습니다.

# %% [markdown]
# ![설명](images/screenshot%202026-09-14%20155617.png)
